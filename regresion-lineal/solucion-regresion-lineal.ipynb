# %% [markdown]
# # INGRESOS MENSUALES

# %% [markdown]
# # 1. Generamos un conjunto de datos

# %%
import numpy as np

#Generamos los años de experiencia
X = 20 * np.random.rand(100, 1)
X

#Generamos los ingresos

ruido = 5 * np.random.randn(100, 1) # Variabilidad de +/- 5k
y = 30 + (4 * X) + ruido
y
# Out:
# array([[ 96.50100871],
#        [118.26546556],
#        [ 74.75989212],
#        [ 84.01816956],
#        [ 37.57005725],
#        [ 40.99991355],
#        [ 49.16203029],
#        [ 52.47826446],
#        [ 82.28672908],
#        [ 98.65611945],
#        [109.41373193],
#        [ 43.026015  ],
#        [111.29888566],
#        [ 91.84987204],
#        [ 65.97488855],
#        [ 59.45713949],
#        [ 26.17209254],
#        [ 80.99732405],
#        [ 61.93969574],
#        [110.23659005],
#        [ 46.17643836],
#        [ 80.23631986],
#        [ 87.12623439],
#        [ 84.91086707],
#        [ 61.29748365],
#        [ 71.66145518],
#        [ 49.53305767],
#        [ 70.76330293],
#        [106.17842537],
#        [ 57.84412559],
#        [ 60.42761228],
#        [104.45260058],
#        [ 43.70112318],
#        [ 74.69713301],
#        [ 54.52083421],
#        [ 76.99234599],
#        [ 39.70676986],
#        [ 60.58044758],
#        [ 53.7649764 ],
#        [ 99.37987735],
# ...

# %% [markdown]
# # 2. Ajustamos el modelo de regresion lineal

# %%
import matplotlib.pyplot as plt
plt.plot(X, y, "b.")
plt.show()
