# %% [markdown]
# <h1><font color="#113D68" size=6>Deep Learning en Python con PyTorch</font></h1>
#
# <h1><font color="#113D68" size=5>Parte 5. Modelos avanzados</font></h1>
#
# <h1><font color="#113D68" size=4>3. Construir una Red Neuronal Convolucional</font></h1>
#
# <br><br>
# <div style="text-align: right">
# <font color="#113D68" size=3>Manuel Castillo Cara</font><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# More information about [Manuel Castillo-Cara](https://www.manuelcastillo.eu/)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Puedes ver más cursos de Inteligencia Artificial, Machine Learning y Deep Learning en mi [página web](https://www.manuelcastillo.eu/udemy/)

# %% [markdown]
# ---
#
# <a id="indice"></a>
# <h2><font color="#004D7F" size=5>Índice</font></h2>
#
# * [0. Contexto](#section0)
# * [1. Redes neuronales convolucionales](#section1)
# * [2. Arquitectura de las Redes Neuronales Convolucionales](#section2)
# * [3. Ejemplo de Red Neuronal Convolucional](#section3)
# * [4. Mapas de características](#section4)

# %% [markdown]
# ---
# <a id="section0"></a>
# # <font color="#004D7F" size=6> 0. Contexto</font>

# %% [markdown]
# Las redes neuronales se construyen con capas conectadas entre sí. Existen diferentes tipos de capas. Para aplicaciones relacionadas con imágenes, siempre encontrarás capas convolucionales. Estas capas tienen muy pocos parámetros, pero se aplican sobre una entrada de gran tamaño. Son poderosas porque pueden preservar la estructura espacial de la imagen. Por lo tanto, se utilizan para producir resultados en visión por computadora. Después de completar esta clase, sabrás:
#
# - Qué son las capas convolucionales y las capas de pooling
# - Cómo encajan en una red neuronal
# - Cómo se diseña una red neuronal que usa capas convolucionales

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# [PyTorch tutorials.](https://pytorch.org/tutorials/)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Artículo científico: [Vincent Dumoulin and Francesco Visin. _A guide to convolution arithmetic for deep learning_,
# 2016.](https://arxiv.org/abs/1603.07285)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# PyTorch tutorials: [Training a Classifier](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html).

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section1"></a>
# # <font color="#004D7F" size=6>1. Redes neuronales convolucionales</font>

# %% [markdown]
# - Ejemplo: Redes neuronales para procesar imágenes en escala de grises:
#
#   - Caso más simple en visión por computadora con aprendizaje profundo
#
# - Características de una imagen en escala de grises o RGB:
#
#   - Arreglo de píxeles
#
#   - Cada píxel: valor entre 0 y 255
#
#   - Ejemplo: imagen 32x32 = 1024 píxeles
#
# - Desafíos para redes neuronales tradicionales:
#
#   - Primera capa requeriría al menos 1024 pesos de entrada
#
#   - Dificultad para extraer información útil de valores de píxeles individuales
#
#   - Importancia de la estructura espacial (ej. líneas horizontales o verticales)
#
# - Ventajas de las redes neuronales convolucionales (CNN):
#
#   - Uso de capas convolucionales para preservar información espacial
#
#   - Aprendizaje de relaciones entre píxeles vecinos
#
#   - Generación de representaciones de características
#
# - Características clave de las CNN:
#   - Invariancia a ciertas distorsiones (color, rotación, escala)
#
#   - Menor número de pesos, facilitando el entrenamiento
#
# - Beneficios de las CNN para procesamiento de imágenes:
#   - Mejor capacidad para extraer información relevante
#
#   - Mayor robustez frente a variaciones en la imagen de entrada

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Más información sobre [`Redes Neuronales Convolucionales`](https://towardsdatascience.com/a-comprehensive-guide-to-convolutional-neural-networks-the-eli5-way-3bd2b1164a53)

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section2"></a>
# # <font color="#004D7F" size=6>2. Arquitectura de las Redes Neuronales Convolucionales</font>

# %% [markdown]
# Esta estructura permite a las CNN procesar eficientemente imágenes, extrayendo características relevantes y realizando tareas como clasificación de manera efectiva.
#
# - Tipos de capas en una red neuronal convolucional simple:
#   1. Capas convolucionales
#
#   2. Capas de pooling
#
#   3. Capas completamente conectadas
#
# - **Capa de convolución**:
#   - Neuronas llamadas "filtros"
#
#   - Usualmente convolución 2D para imágenes
#
#   - Filtro: parche 2D (ej. 3x3 píxeles)
#
#   - Campo receptivo: tamaño del parche
#
#   - Proceso: multiplicación y suma de píxeles
#
#   - Múltiples filtros generan mapas de características
#
#   - Salida: tensor de mapas de características apilados
#
# - Función de los mapas de características:
#   - Aprenden características de la imagen
#
#   - Ejemplo: detección de líneas verticales
#
#   - Capas apiladas infieren características de alto nivel
#
# - **Capa de Agrupación (Pooling)**:
#   - Reduce el muestreo de mapas de características
#
#   - Consolida características aprendidas
#
#   - Comprime y generaliza representaciones
#
#   - Tipos: average pooling, max pooling
#
# - **Capa totalmente conectada**:
#   - Generalmente en las capas finales
#
#   - Procesa características consolidadas
#
#   - Produce la predicción final
#
#   - Puede haber varias capas apiladas
#
#   - En clasificación: última capa seguida de función softmax
#
# <center>
# <figure>
#   <img src="Datasets/5_1-cnn.png" width="350" height="150" alt="Netron">
#   <figcaption><blockquote>Ejemplo de un Filtro Aplicado a una Entrada Bidimensional para Crear un Mapa de Características</blockquote></figcaption>
# </figure>
# </center>

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section3"></a>
# # <font color="#004D7F" size=6>3. Ejemplo de Red Neuronal Convolucional</font>

# %% [markdown]
# Este código demuestra una implementación práctica de una CNN para clasificación de imágenes, utilizando herramientas y técnicas estándar en el campo del aprendizaje profundo para visión por computadora.
#
# - Programa: Clasificación de imágenes en CIFAR-10
#
# - Características del conjunto de datos CIFAR-10:
#   - Imágenes de 32x32 píxeles
#
#   - Color RGB (3 canales)
#
#   - 10 clases (etiquetadas de 0 a 9)
#
# - Uso de torchvision:
#   - Librería hermana de PyTorch para visión por computadora
#
#   - Descarga y transformación del conjunto CIFAR-10 a tensor PyTorch
#
# - Utilización de `DataLoader`:
#   - Ayuda a crear lotes para el entrenamiento
#
# - Proceso de entrenamiento:
#   - Optimiza la pérdida de entropía cruzada
#
#   - Utiliza descenso de gradiente estocástico
#
# - Cálculo de accuracy:
#   - Más intuitivo que la entropía cruzada para clasificación
#
#   - Calculado al final de cada época
#
#   - Fórmula:
#     ```python
#     acc += (torch.argmax(y_pred, 1) == labels).float().sum()
#     ```
#
# - Componentes clave del código:
#   1. Carga y preprocesamiento de datos
#
#   2. Definición de la arquitectura de la CNN
#
#   3. Configuración del optimizador y función de pérdida
#
#   4. Bucle de entrenamiento con cálculo de accuracy
#
#   5. Evaluación en conjunto de prueba

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Más información sobre el dataset [`CIFAR-10`](https://www.cs.toronto.edu/~kriz/cifar.html).

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Más información sobre [`Conv2d`](https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html).

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <i class="fa fa-info-circle" aria-hidden="true"></i>
# Más información sobre [`MaxPool2d`](https://pytorch.org/docs/stable/generated/torch.nn.MaxPool2d.html).

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision

# convierte cada imagen en un tensor de PyTorch y también normaliza los valores de los píxeles
# para que estén en el rango [0, 1] (originalmente están en [0, 255]).
transform = torchvision.transforms.Compose(
    [torchvision.transforms.ToTensor()])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

batch_size = 32
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)
# Out:
# 100.0%

# %%
class CIFAR10Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=(3, 3), stride=1, padding=1) #3 canales, 32 características, kernel_size de 3x3
        self.act1 = nn.ReLU()
        self.drop1 = nn.Dropout(0.3)

        self.pool1 = nn.MaxPool2d(2, 2) #tamaño del kernel de 2x2

        self.conv2 = nn.Conv2d(32, 32, kernel_size=(3, 3), stride=1, padding=1) #32 de entrada, 32 características, kernel_size de 3x3
        self.act2 = nn.ReLU()
        self.drop2 = nn.Dropout(0.3)

        self.pool2 = nn.MaxPool2d(2,2)

        self.flat = nn.Flatten()

        self.fc3 = nn.Linear(2048, 512)
        self.act3 = nn.ReLU()
        self.drop3 = nn.Dropout(0.5)

        self.fc4 = nn.Linear(512, 10)

    def forward(self, x):
        #input 3x32x32 - output 32x32x32
        x = self.act1(self.conv1(x))
        x = self.drop1(x)

        #input 32x32x32 - output 32x16x16
        x = self.pool1(x)

        # input 32x16x16-output 32x16x16
        x = self.act2(self.conv2(x))
        x = self.drop2(x)

        #input 32x16x16 - output 32x8x8
        x = self.pool2(x)

        #input 32x8x8 - output 2048
        x = self.flat(x)

        x = self.act3(self.fc3(x))
        x = self.drop3(x)

        x = self.fc4(x)
        return x

# %%
model = CIFAR10Model()
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
model.to(device)

n_epochs = 20
for epoch in range(n_epochs):
    for inputs, labels in trainloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        y_pred = model(inputs)
        loss = loss_fn(y_pred, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    acc = 0
    count = 0
    for inputs, labels in testloader:
        inputs = inputs.to(device)
        labels = labels.to(device)
        y_pred = model(inputs)
        acc += (torch.argmax(y_pred, 1) == labels).float().sum()
        count += len(labels)
    acc = acc/count
    print("Época %d: accuracy del modelo %.2f%%" % (epoch, acc*100))

torch.save(model.state_dict(), 'cifar10_model.pth')
# Out:
# cpu
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 11
#       7 model.to(device)
#       8
#       9 n_epochs = 20
#      10 for epoch in range(n_epochs):
# ---> 11     for inputs, labels in trainloader:
#      12         inputs = inputs.to(device)
#      13         labels = labels.to(device)
#      14         y_pred = model(inputs)
#
# File c:\Users\JORGE\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:718, in _BaseDataLoaderIter.__next__(self)
#     715 if self._sampler_iter is None:
#     716     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     717     self._reset()  # type: ignore[call-arg]
# --> 718 data = self._next_data()
#     719 self._num_yielded += 1
#     720 if (
#     721     self._dataset_kind == _DatasetKind.Iterable
#     722     and self._IterableDataset_len_called is not None
# ...

# %% [markdown]
# ---
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---

# %% [markdown]
# <a id="section4"></a>
# # <font color="#004D7F" size=6>4. Mapas de características</font>

# %% [markdown]
# Este análisis ayuda a comprender cómo las CNN procesan y transforman la información visual a través de sus capas, desde características simples en las primeras capas hasta representaciones más complejas en las capas posteriores.
#
# - Estructura de la red:
#   - 2 capas convolucionales
#
# - Características de las capas convolucionales:
#   1. Primera capa convolucional:
#
#      - Tamaño de kernel: 3x3
#
#      - Entrada: Imagen RGB (3 canales)
#
#      - Analiza 9 píxeles (3x3) con 3 valores cada uno
#
#   2. Segunda capa convolucional:
#      - Tamaño de kernel: 3x3
#
#      - Entrada: Mapa de características con 32 canales
#
#      - Analiza 9 "píxeles" con 32 valores cada uno
#
#      - Más parámetros que la primera capa
#
# - Análisis del mapa de características:
#   - Selección de una muestra del conjunto de entrenamiento
#
#   - Ejemplo: Imagen de un caballo
#
# - Características de la imagen de entrada:
#   - Tamaño: 32x32 píxeles
#
#   - Canales: RGB
#
# - Importancia del análisis:
#   - Permite entender cómo la red procesa la información
#
#   - Muestra la transformación de la imagen a través de las capas
#
# - Consideraciones:
#   - La complejidad aumenta en capas más profundas
#
#   - Cada capa extrae características más abstractas
#
# - Ventajas de esta estructura:
#   - Permite capturar características jerárquicas
#
#   - Eficiente en el procesamiento de imágenes

# %%
import matplotlib.pyplot as plt

model.load_state_dict(torch.load('cifar10_model.pth'))

plt.imshow(trainset.data[7])
plt.show()

# %% [markdown]
# Este proceso permite examinar cómo la primera capa convolucional transforma la imagen de entrada, proporcionando insights sobre las características iniciales que la red aprende a detectar.
#
# - Preparación de la imagen para el modelo PyTorch:
#   - Conversión a tensor de PyTorch
#
#   - Creación de un lote con una sola imagen
#
# - Formato requerido por modelos PyTorch:
#   - Tensor con formato (canal, altura, ancho)
#
#   - Datos originales generalmente, e.g., en formato (altura, ancho, canal)
#
#   ![image.png](data:image/png;base64,...)
#
# - Uso de `torchvision`:
#   - Realiza automáticamente la conversión de formato
#
#   - Alternativa: Permutar manualmente las dimensiones
#
# - Proceso de análisis:
#   1. Pasar la imagen por la primera capa convolucional
#
#   2. Capturar la salida de la capa
#
# - Consideración importante:
#   - Usar `torch.no_grad()` para evitar cálculo de gradientes
#
#   - No se está optimizando el peso del modelo
#
# - Ventajas de este enfoque:
#   - Permite visualizar las características extraídas por la primera capa
#
#   - Ayuda a entender cómo la red procesa la información inicial
#
# - Consideraciones adicionales:
#   - La salida será un mapa de características
#
#   - Cada canal del mapa representa una característica diferente

# %%
X = torch.tensor([trainset.data[7]], dtype=torch.float32)
X = X.permute(0, 3, 1, 2)
model.eval()
# Out:
# /tmp/ipykernel_3335/3445145958.py:1: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   X = torch.tensor([trainset.data[7]], dtype=torch.float32)
# CIFAR10Model(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act1): ReLU()
#   (drop1): Dropout(p=0.3, inplace=False)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (act2): ReLU()
#   (drop2): Dropout(p=0.3, inplace=False)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flat): Flatten(start_dim=1, end_dim=-1)
#   (fc3): Linear(in_features=2048, out_features=512, bias=True)
#   (act3): ReLU()
# ...

# %% [markdown]
# - Significado de "mapas de características":
#   - Resaltan características específicas de la imagen de entrada
#
# - Proceso de identificación de características:
#   - Uso de una pequeña ventana (filtro)
#
#   - En este caso: filtro de 3x3 píxeles
#
# - Aplicación de filtros en imagen RGB:
#   - Cada canal de color recibe un filtro diferente
#
#   - Combinación de resultados para generar característica de salida
#
# - Visualización de la segunda capa convolucional:
#   - Similar al proceso de la primera capa
#
#   - Revela características más complejas
#
# - Interpretación de los resultados:
#   - Cada subgráfico representa un canal diferente del mapa de características
#
#   - Patrones más abstractos y complejos en la segunda capa
#
# - Importancia de esta visualización:
#   - Ayuda a entender cómo la red procesa la información en capas más profundas
#
#   - Muestra la progresión de la extracción de características
#
# - Consideraciones:
#   - Las características se vuelven más abstractas en capas más profundas
#
#   - Puede ser más difícil interpretar visualmente capas posteriores

# %%
with torch.no_grad():
  feature_maps = model.conv1(X.to(device))
fig, ax = plt.subplots(4, 8, sharex=True, sharey=True, figsize=(16,8))
for i in range(0, 32):
    row, col = i//8, i%8
    ax[row][col].imshow(feature_maps[0][i].cpu().numpy())
plt.show()

# %% [markdown]
# Esta observación ilustra cómo las CNNs construyen representaciones cada vez más abstractas y útiles a medida que se profundiza en la red, mejorando su capacidad para reconocer y clasificar objetos complejos en imágenes.
#
# - Comparación de mapas de características:
#   - Segunda capa convolucional vs. primera capa
#
# - Características de los mapas de la segunda capa:
#   - Más borrosos
#
#   - Más abstractos
#
# - Utilidad de los mapas de la segunda capa:
#   - Más efectivos para la identificación de objetos
#
# - Razones de la mayor utilidad:
#   - Capturan características de más alto nivel
#
#   - Combinan información de múltiples características de bajo nivel
#
# - Progresión de la abstracción:
#   - Primera capa: características simples (bordes, texturas)
#
#   - Segunda capa: patrones más complejos y abstractos
#
# - Importancia en la arquitectura de la red:
#   - Demuestra la jerarquía de aprendizaje en
#
#   - Justifica el uso de múltiples capas convolucionales

# %%
with torch.no_grad():
    feature_maps = model.act1(model.conv1(X.to(device)))
    feature_maps = model.drop1(feature_maps)
    #feature_maps = model.pool1(feature_maps)
    feature_maps = model.conv2(feature_maps)
fig, ax = plt.subplots(4, 8, sharex=True, sharey=True, figsize=(16,8))
for i in range(0, 32):
    row, col = i//8, i%8
    ax[row][col].imshow(feature_maps[0][i].cpu().numpy())
plt.show()

# %% [markdown]
# <div style="text-align: right"> <font size=5> <a href="#indice"><i class="fa fa-arrow-circle-up" aria-hidden="true" style="color:#004D7F"></i></a></font></div>
#
# ---
#
# <div style="text-align: right"> <font size=6><i class="fa fa-coffee" aria-hidden="true" style="color:#004D7F"></i> </font></div>
